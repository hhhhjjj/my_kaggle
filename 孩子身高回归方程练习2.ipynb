# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
height = pd.read_csv('height_train.csv')
test = pd.read_csv('height_test.csv')
real = pd.read_csv('height_real.csv')

# %%
model = LinearRegression()
model.fit(X=height.loc[:,['father_height','mother_height','boy_dummy']],y=height.child_height)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([0.23959427, 0.25013358, 0.10030806])

# %%
model.intercept_
# Out:
# 0.8274299645517075

# %%
# 1. 构造方程预测
test['prediction'] = 0.23959427*test.father_height+0.25013358*test.mother_height+0.10030806*test.boy_dummy+0.8274299645517075

# %%
# 2. 直接使用模型的predict()
test['prediction'] = model.predict(test.loc[:,['father_height','mother_height','boy_dummy']])

# %%
def evaluate(prediction_path,real_path):
    predict = pd.read_csv(prediction_path)
    real = pd.read_csv(real_path)
    predict = predict.loc[:,['id','prediction']]
    real = real.loc[:,['id','child_height']]
    real = real.merge(predict,on='id',how='left')
    return np.square(real.prediction*100-real.child_height*100).mean()

# %%
np.square(test.prediction*100-real.child_height*100).mean()
# Out:
# 1.1214936229812968

# %%
real
# Out:
#        id  father_height  mother_height  boy_dummy  child_height
# 0    5000           1.71           1.66          0          1.66
# 1    5001           1.69           1.63          1          1.74
# 2    5002           1.71           1.56          1          1.74
# 3    5003           1.68           1.67          1          1.72
# 4    5004           1.71           1.60          0          1.63
# 5    5005           1.88           1.59          1          1.78
# 6    5006           1.72           1.62          0          1.64
# 7    5007           1.71           1.64          1          1.72
# 8    5008           1.73           1.69          1          1.76
# 9    5009           1.77           1.61          0          1.65
# 10   5010           1.72           1.64          0          1.66
# 11   5011           1.74           1.65          0          1.65
# 12   5012           1.68           1.65          1          1.73
# 13   5013           1.79           1.68          0          1.69
# 14   5014           1.75           1.61          0          1.64
# 15   5015           1.65           1.61          1          1.73
# 16   5016           1.70           1.56          0          1.62
# 17   5017           1.80           1.58          0          1.64
# 18   5018           1.65           1.63          0          1.64
# 19   5019           1.71           1.69          0          1.67
# 20   5020           1.75           1.63          0          1.65
# 21   5021           1.72           1.66          0          1.67
# 22   5022           1.79           1.65          0          1.68
# 23   5023           1.75           1.55          0          1.62
# 24   5024           1.73           1.65          0          1.67
# 25   5025           1.75           1.64          1          1.78
# 26   5026           1.76           1.63          0          1.65
# 27   5027           1.76           1.68          1          1.75
# 28   5028           1.77           1.55          0          1.63
# 29   5029           1.68           1.64          1          1.74
# ..    ...            ...            ...        ...           ...
# 970  5970           1.73           1.61          1          1.72
# 971  5971           1.65           1.55          1          1.70
# 972  5972           1.68           1.63          0          1.63
# 973  5973           1.72           1.63          1          1.73
# 974  5974           1.73           1.57          1          1.74
# 975  5975           1.76           1.67          0          1.67
# 976  5976           1.71           1.66          1          1.76
# 977  5977           1.69           1.57          0          1.63
# 978  5978           1.71           1.70          1          1.75
# 979  5979           1.70           1.57          0          1.63
# 980  5980           1.71           1.55          1          1.73
# 981  5981           1.66           1.55          0          1.61
# 982  5982           1.64           1.61          0          1.62
# 983  5983           1.79           1.63          0          1.66
# 984  5984           1.71           1.68          0          1.64
# 985  5985           1.76           1.62          1          1.75
# 986  5986           1.73           1.59          0          1.64
# 987  5987           1.80           1.66          1          1.78
# 988  5988           1.78           1.59          1          1.76
# 989  5989           1.79           1.64          1          1.78
# 990  5990           1.74           1.58          1          1.74
# 991  5991           1.72           1.58          0          1.62
# 992  5992           1.71           1.69          1          1.75
# 993  5993           1.81           1.70          0          1.68
# 994  5994           1.76           1.65          1          1.77
# 995  5995           1.77           1.61          1          1.76
# 996  5996           1.65           1.65          1          1.72
# 997  5997           1.83           1.69          0          1.67
# 998  5998           1.79           1.63          0          1.66
# 999  5999           1.75           1.61          0          1.66
#
# [1000 rows x 5 columns]

# %%
# 我上次的代码就是加上了性别乘父亲身高，性别乘母亲身高
# 还有父母身高的差值
